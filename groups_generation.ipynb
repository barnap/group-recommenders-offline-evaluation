# %%
import settings.config as cfg

preprocessed_dataset_folder = cfg.preprocessed_dataset_folder
group_sizes_to_test = cfg.group_sizes_to_test
group_similarity_to_test = cfg.group_similarity_to_test
group_number = cfg.group_number

print(group_number)
# Out:
# 50

# %%
import pandas as pd

ratings_df = pd.read_csv(preprocessed_dataset_folder+"/ratings.csv") 
display(ratings_df.head(10))
# Out:
#    user  item  rating
# 0     1  1193       5
# 1     1   661       3
# 2     1   914       3
# 3     1  3408       4
# 4     1  2355       5
# 5     1  1197       3
# 6     1  1287       5
# 7     1  2804       5
# 8     1   594       4
# 9     1   919       4

# %%
# computing similarity between each pair of users

import numpy as np

user_matrix = ratings_df.pivot_table(columns='item', index='user', values='rating')

user_id_set = set(ratings_df['user'])
user_id_indexes = user_matrix.index.values
user_matrix = user_matrix.fillna(0)
numpy_array = user_matrix.to_numpy()
sim_matrix = np.corrcoef(numpy_array)

# display(sim_matrix)
# display(list(user_id_indexes))
# display(user_id_set)

# %%
import random
random.seed(1010101)

# Auxiliary functions from Kaya et al 
# https://github.com/mesutkaya/recsys2020/blob/8a8c7088bebc3309b8517f62248386ea7be39776/GFAR_python/create_group.py
def select_user_for_sim_group(group, sim_matrix, user_id_indexes, sim_threshold=0.3):
    '''
    Helper function to the generate_similar_user_groups function. Given already selected group members, it randomly
    selects from the remaining users that has a PCC value >= sim_threshold to any of the existing members.
    :param group:
    :param sim_matrix:
    :param user_id_indexes:
    :param sim_threshold: 0.5 is large size effect, 0.3 medium and 0.1 is small based on research (add citation!)
    :return:
    '''
    ids_to_select_from = set()
    for member in group:
        member_index = user_id_indexes.tolist().index(member)
        indexes = np.where(sim_matrix[member_index] >= sim_threshold)[0].tolist()
        user_ids = [user_id_indexes[index] for index in indexes]
        ids_to_select_from = ids_to_select_from.union(set(user_ids))
    candidate_ids = ids_to_select_from.difference(set(group))
    if len(candidate_ids) == 0:
        return None
    else:
        selection = random.sample(candidate_ids, 1)
        return selection[0]
    
    
def select_user_for_divergent_group(group, sim_matrix, user_id_indexes, sim_threshold=0.1):
    '''
    Helper function to the generate_similar_user_groups function. Given already selected group members, it randomly
    selects from the remaining users that has a PCC value < sim_threshold to any of the existing members.
    :param group:
    :param sim_matrix:
    :param user_id_indexes:
    :param sim_threshold: 0.5 is large size effect, 0.3 medium and 0.1 is small based on research (add citation!)
    :return:
    '''
    ids_to_select_from = set()
    for member in group:
        member_index = user_id_indexes.tolist().index(member)
        indexes = np.where(sim_matrix[member_index] < sim_threshold)[0].tolist()
        user_ids = [user_id_indexes[index] for index in indexes]
        ids_to_select_from = ids_to_select_from.union(set(user_ids))
    candidate_ids = ids_to_select_from.difference(set(group))
    if len(candidate_ids) == 0:
        return None
    else:
        selection = random.sample(candidate_ids, 1)
        return selection[0]


# generation of random, similar and divergent groups, revised from Kaya et al 
# https://github.com/mesutkaya/recsys2020/blob/8a8c7088bebc3309b8517f62248386ea7be39776/GFAR_python/create_group.py
def generate_random_groups(user_id_set):
    groups_list = list()
    for group_size in group_sizes_to_test:
        for i in range(group_number):
            group = random.sample(user_id_set, group_size)
            groups_list.append({"group_size" : group_size, "group_similarity" : 'random', "group_members" : group})
    return groups_list


def generate_similar_groups(user_id_indexes, similarity_matrix):
    groups_list = list()
    for group_size in group_sizes_to_test:
        groups_size_list = list()
        while(len(groups_size_list) < group_number):
            group = random.sample(user_id_set, 1)
            while len(group) < group_size:
                new_member = select_user_for_sim_group(group, similarity_matrix, user_id_indexes, sim_threshold=0.3)
                if new_member is None:
                    break
                group.append(new_member)
            if len(group) == group_size:
                groups_size_list.append({"group_size" : group_size, "group_similarity" : 'similar', "group_members" : group})
        groups_list.extend(groups_size_list)
        print(len(groups_list))
    return groups_list

def generate_divergent_groups(user_id_indexes, similarity_matrix):
    groups_list = list()
    for group_size in group_sizes_to_test:
        groups_size_list = list()
        while(len(groups_size_list) < group_number):
            group = random.sample(user_id_set, 1)
            while len(group) < group_size:
                new_member = select_user_for_divergent_group(group, similarity_matrix, user_id_indexes, sim_threshold=0.1)
                if new_member is None:
                    break
                group.append(new_member)
            if len(group) == group_size:
                groups_size_list.append({"group_size" : group_size, "group_similarity" : 'divergent', "group_members" : group})
        groups_list.extend(groups_size_list)
        print(len(groups_list))
    return groups_list



def generate_similar_with_one_divergent_groups(user_id_indexes, similarity_matrix):
    groups_list = list()
    for group_size in group_sizes_to_test:
        groups_size_list = list()
        while(len(groups_size_list) < group_number):
            group = random.sample(user_id_set, 1)
            while len(group) < (group_size-1):
                new_member = select_user_for_sim_group(group, similarity_matrix, user_id_indexes, sim_threshold=0.3)
                if new_member is None:
                    break
                group.append(new_member)
            
            dissimilar_member = select_user_for_divergent_group(group, similarity_matrix, user_id_indexes, sim_threshold=0.1)
            group.append(dissimilar_member)
            
            if len(group) == group_size:
                groups_size_list.append({"group_size" : group_size, "group_similarity" : 'similar_one_divergent', "group_members" : group})
        groups_list.extend(groups_size_list)
        print(len(groups_list))
    return groups_list

# %%
group_list_random = generate_random_groups(user_id_set)
display(len(group_list_random))

group_list_similar = generate_similar_groups(user_id_indexes, sim_matrix)
display(len(group_list_similar))

group_list_divergent = generate_divergent_groups(user_id_indexes, sim_matrix)
display(len(group_list_divergent))

group_list_sim_one_div = generate_similar_with_one_divergent_groups(user_id_indexes, sim_matrix)
display(len(group_list_sim_one_div))
# Out:
# 200
# 50
# 100
# 150
# 200
# 200
# 50
# 100
# 150
# 200
# 200
# 50
# 100
# 150
# 200
# 200

# %%
group_list = group_list_random + group_list_similar + group_list_divergent + group_list_sim_one_div
#group_list = group_list_sim_one_div

group_dict = dict()
for group_id, group in zip(range(len(group_list)), group_list):
    group_dict[group_id] = group
display(group_dict)
# Out:
# {0: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [4805, 5428]},
#  1: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [5251, 146]},
#  2: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [3916, 4539]},
#  3: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [2059, 5558]},
#  4: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1789, 463]},
#  5: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [3234, 4068]},
#  6: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [5216, 4855]},
#  7: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [339, 5736]},
#  8: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [153, 4515]},
#  9: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [3450, 2157]},
#  10: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [707, 2380]},
#  11: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [379, 3986]},
#  12: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [3752, 3705]},
#  13: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [209, 1288]},
#  14: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [3929, 751]},
#  15: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [4751, 497]},
#  16: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [3308, 197]},
#  17: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [417, 1226]},
#  18: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [4699, 5990]},
#  19: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [2498, 3463]},
#  20: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [3193, 4620]},
#  21: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [3834, 4336]},
#  22: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [2327, 2358]},
#  23: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [671, 1532]},
#  24: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [5896, 5350]},
#  25: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [4113, 3112]},
#  26: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [602, 404]},
#  27: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1534, 3293]},
#  28: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [3740, 3842]},
#  29: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [5716, 3111]},
#  30: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1867, 4910]},
#  31: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [2163, 4817]},
#  32: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1723, 2447]},
#  33: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1826, 1002]},
#  34: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [2720, 5726]},
#  35: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [3355, 5375]},
#  36: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [4455, 1427]},
#  37: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [4391, 5096]},
#  38: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [2218, 4055]},
#  39: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [4617, 2873]},
#  40: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1551, 2534]},
#  41: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [5334, 4506]},
#  42: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [867, 3743]},
#  43: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [729, 3771]},
#  44: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [1969, 3791]},
#  45: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [75, 1891]},
#  46: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [6036, 4306]},
#  47: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [4495, 5157]},
#  48: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [5470, 2348]},
#  49: {'group_size': 2,
#   'group_similarity': 'random',
#   'group_members': [2466, 2433]},
#  50: {'group_size': 3,
#   'group_similarity': 'random',
#   'group_members': [4787, 2909, 5884]},
#  51: {'group_size': 3,
#   'group_similarity': 'random',
#   'group_members': [1140, 2307, 4005]},
#  52: {'group_size': 3,
#   'group_similarity': 'random',
#   'group_members': [3306, 3542, 1514]},
#  53: {'group_size': 3,
#   'group_similarity': 'random',
#   'group_members': [
{'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5103, 1358, 1667, 5961, 164]},
#  751: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4280, 1149, 5232, 5953, 4848]},
#  752: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1723, 422, 4868, 472, 4459]},
#  753: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [913, 2270, 4132, 3812, 1535]},
#  754: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3931, 2818, 2020, 4884, 799]},
#  755: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5584, 2352, 4972, 4317, 2094]},
#  756: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3457, 4607, 2929, 4480, 4297]},
#  757: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2665, 533, 1019, 5371, 3239]},
#  758: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5743, 2704, 2676, 1668, 3416]},
#  759: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3101, 1380, 2523, 1260, 5939]},
#  760: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3938, 554, 3193, 4721, 5502]},
#  761: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1783, 745, 1226, 361, 1507]},
#  762: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2072, 5764, 4645, 2423, 4228]},
#  763: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1879, 2098, 3513, 4141, 4770]},
#  764: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4213, 3957, 4261, 5568, 3842]},
#  765: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3978, 33, 5621, 5355, 5907]},
#  766: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1658, 2288, 3469, 4193, 2089]},
#  767: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2306, 759, 2745, 1757, 5715]},
#  768: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5552, 5564, 5789, 5928, 2487]},
#  769: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4047, 7, 5490, 3125, 4108]},
#  770: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1949, 2787, 3161, 1280, 647]},
#  771: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1265, 1842, 2472, 5826, 3852]},
#  772: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5285, 5495, 4394, 2052, 338]},
#  773: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2692, 2142, 3913, 3334, 2496]},
#  774: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3643, 669, 3065, 4390, 4111]},
#  775: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5357, 815, 2551, 2286, 3237]},
#  776: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [905, 316, 1440, 4621, 3106]},
#  777: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [611, 5654, 2969, 2436, 2767]},
#  778: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5081, 934, 777, 3336, 4346]},
#  779: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4890, 2170, 919, 3547, 4173]},
#  780: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2703, 3789, 514, 3123, 2732]},
#  781: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3101, 302, 3285, 984, 2280]},
#  782: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5959, 1345, 927, 3713, 5865]},
#  783: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3452, 5777, 451, 671, 1627]},
#  784: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5813, 803, 5301, 3763, 4653]},
#  785: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [752, 1202, 2462, 2181, 2218]},
#  786: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2904, 1406, 4630, 3606, 4928]},
#  787: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1860, 2393, 5026, 5232, 5928]},
#  788: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2825, 5974, 2376, 2608, 3993]},
#  789: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3945, 1930, 5256, 2996, 4226]},
#  790: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4882, 245, 2685, 1632, 2217]},
#  791: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3132, 893, 429, 4310, 1115]},
#  792: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [261, 3125, 329, 1542, 1178]},
#  793: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [809, 4181, 5896, 736, 98]},
#  794: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4081, 2723, 1770, 3058, 4157]},
#  795: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5715, 2469, 3047, 623, 5599]},
#  796: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2992, 2081, 3542, 1037, 5867]},
#  797: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [671, 2008, 2446, 1676, 3759]},
#  798: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2038, 4510, 415, 1137, 4444]},
#  799: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5610, 2570, 137, 5490, 5338]}}

# %%
# simple similarity viewer per group
np.set_printoptions(precision=4, suppress=True)
idx = 80
member_index = [user_id_indexes.tolist().index(member) for member in group_dict[idx]["group_members"]]
s = sim_matrix[member_index]
s[:,member_index]
# Out:
# array([[1.    , 0.0383, 0.012 ],
#        [0.0383, 1.    , 0.1097],
#        [0.012 , 0.1097, 1.    ]])

# %%
import pickle
pickle.dump(group_dict, open(preprocessed_dataset_folder+"/group_composition.pkl", "wb"))
