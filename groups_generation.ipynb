# %%
import settings.config as cfg

preprocessed_dataset_folder = cfg.preprocessed_dataset_folder
group_sizes_to_test = cfg.group_sizes_to_test
group_similarity_to_test = cfg.group_similarity_to_test
group_number = cfg.group_number

print(group_number)
# Out:
# 50

# %%
import pandas as pd

ratings_df = pd.read_csv(preprocessed_dataset_folder+"/ratings.csv") 
display(ratings_df.head(10))
# Out:
#    user  item  rating
# 0     1  1193       5
# 1     1   661       3
# 2     1   914       3
# 3     1  3408       4
# 4     1  2355       5
# 5     1  1197       3
# 6     1  1287       5
# 7     1  2804       5
# 8     1   594       4
# 9     1   919       4

# %%
# computing similarity between each pair of users

import numpy as np

user_matrix = ratings_df.pivot_table(columns='item', index='user', values='rating')

user_id_set = set(ratings_df['user'])
user_id_indexes = user_matrix.index.values
user_matrix = user_matrix.fillna(0)
numpy_array = user_matrix.to_numpy()
sim_matrix = np.corrcoef(numpy_array)

# display(sim_matrix)
# display(list(user_id_indexes))
# display(user_id_set)

# %%
import random
random.seed(1010101)

# Auxiliary functions from Kaya et al 
# https://github.com/mesutkaya/recsys2020/blob/8a8c7088bebc3309b8517f62248386ea7be39776/GFAR_python/create_group.py
def select_user_for_sim_group(group, sim_matrix, user_id_indexes, sim_threshold=0.3):
    '''
    Helper function to the generate_similar_user_groups function. Given already selected group members, it randomly
    selects from the remaining users that has a PCC value >= sim_threshold to any of the existing members.
    :param group:
    :param sim_matrix:
    :param user_id_indexes:
    :param sim_threshold: 0.5 is large size effect, 0.3 medium and 0.1 is small based on research (add citation!)
    :return:
    '''
    ids_to_select_from = set()
    for member in group:
        member_index = user_id_indexes.tolist().index(member)
        indexes = np.where(sim_matrix[member_index] >= sim_threshold)[0].tolist()
        user_ids = [user_id_indexes[index] for index in indexes]
        ids_to_select_from = ids_to_select_from.union(set(user_ids))
    candidate_ids = ids_to_select_from.difference(set(group))
    if len(candidate_ids) == 0:
        return None
    else:
        selection = random.sample(candidate_ids, 1)
        return selection[0]
    
    
def select_user_for_divergent_group(group, sim_matrix, user_id_indexes, sim_threshold=0.1):
    '''
    Helper function to the generate_similar_user_groups function. Given already selected group members, it randomly
    selects from the remaining users that has a PCC value < sim_threshold to any of the existing members.
    :param group:
    :param sim_matrix:
    :param user_id_indexes:
    :param sim_threshold: 0.5 is large size effect, 0.3 medium and 0.1 is small based on research (add citation!)
    :return:
    '''
    ids_to_select_from = set()
    for member in group:
        member_index = user_id_indexes.tolist().index(member)
        indexes = np.where(sim_matrix[member_index] < sim_threshold)[0].tolist()
        user_ids = [user_id_indexes[index] for index in indexes]
        ids_to_select_from = ids_to_select_from.union(set(user_ids))
    candidate_ids = ids_to_select_from.difference(set(group))
    if len(candidate_ids) == 0:
        return None
    else:
        selection = random.sample(candidate_ids, 1)
        return selection[0]


# generation of random, similar and divergent groups, revised from Kaya et al 
# https://github.com/mesutkaya/recsys2020/blob/8a8c7088bebc3309b8517f62248386ea7be39776/GFAR_python/create_group.py
def generate_random_groups(user_id_set):
    groups_list = list()
    for group_size in group_sizes_to_test:
        for i in range(group_number):
            group = random.sample(user_id_set, group_size)
            groups_list.append({"group_size" : group_size, "group_similarity" : 'random', "group_members" : group})
    return groups_list


def generate_similar_groups(user_id_indexes, similarity_matrix):
    groups_list = list()
    for group_size in group_sizes_to_test:
        groups_size_list = list()
        while(len(groups_size_list) < group_number):
            group = random.sample(user_id_set, 1)
            while len(group) < group_size:
                new_member = select_user_for_sim_group(group, similarity_matrix, user_id_indexes, sim_threshold=0.3)
                if new_member is None:
                    break
                group.append(new_member)
            if len(group) == group_size:
                groups_size_list.append({"group_size" : group_size, "group_similarity" : 'similar', "group_members" : group})
        groups_list.extend(groups_size_list)
        print(len(groups_list))
    return groups_list

def generate_divergent_groups(user_id_indexes, similarity_matrix):
    groups_list = list()
    for group_size in group_sizes_to_test:
        groups_size_list = list()
        while(len(groups_size_list) < group_number):
            group = random.sample(user_id_set, 1)
            while len(group) < group_size:
                new_member = select_user_for_divergent_group(group, similarity_matrix, user_id_indexes, sim_threshold=0.1)
                if new_member is None:
                    break
                group.append(new_member)
            if len(group) == group_size:
                groups_size_list.append({"group_size" : group_size, "group_similarity" : 'divergent', "group_members" : group})
        groups_list.extend(groups_size_list)
        print(len(groups_list))
    return groups_list



def generate_similar_with_one_divergent_groups(user_id_indexes, similarity_matrix):
    groups_list = list()
    for group_size in group_sizes_to_test:
        groups_size_list = list()
        while(len(groups_size_list) < group_number):
            group = random.sample(user_id_set, 1)
            while len(group) < (group_size-1):
                new_member = select_user_for_sim_group(group, similarity_matrix, user_id_indexes, sim_threshold=0.3)
                if new_member is None:
                    break
                group.append(new_member)
            
            dissimilar_member = select_user_for_divergent_group(group, similarity_matrix, user_id_indexes, sim_threshold=0.1)
            group.append(dissimilar_member)
            
            if len(group) == group_size:
                groups_size_list.append({"group_size" : group_size, "group_similarity" : 'similar_one_divergent', "group_members" : group})
        groups_list.extend(groups_size_list)
        print(len(groups_list))
    return groups_list

# %%
#group_list_random = generate_random_groups(user_id_set)
#display(len(group_list_random))

#group_list_similar = generate_similar_groups(user_id_indexes, sim_matrix)
#display(len(group_list_similar))

#group_list_divergent = generate_divergent_groups(user_id_indexes, sim_matrix)
#display(len(group_list_divergent))

group_list_sim_one_div = generate_similar_with_one_divergent_groups(user_id_indexes, sim_matrix)
display(len(group_list_sim_one_div))
# Out:
# 50
# 100
# 150
# 200
# 200

# %%
#group_list = group_list_random + group_list_similar + group_list_divergent + group_list_sim_one_div
group_list = group_list_sim_one_div

group_dict = dict()
for group_id, group in zip(range(len(group_list)), group_list):
    group_dict[group_id] = group
display(group_dict)
# Out:
# {0: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4805, 4502]},
#  1: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5251, 144]},
#  2: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3916, 5891]},
#  3: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2059, 5382]},
#  4: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1789, 424]},
#  5: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3234, 4305]},
#  6: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5216, 5575]},
#  7: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4855, 358]},
#  8: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5736, 163]},
#  9: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4515, 4591]},
#  10: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2157, 722]},
#  11: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2380, 507]},
#  12: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3986, 4857]},
#  13: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3705, 215]},
#  14: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1288, 5375]},
#  15: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [751, 5899]},
#  16: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [497, 3493]},
#  17: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [197, 336]},
#  18: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1226, 4869]},
#  19: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5990, 3528]},
#  20: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3463, 5816]},
#  21: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3193, 5782]},
#  22: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4620, 2956]},
#  23: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4336, 2501]},
#  24: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2358, 809]},
#  25: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1532, 4988]},
#  26: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5350, 4745]},
#  27: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3112, 805]},
#  28: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [404, 1605]},
#  29: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3293, 4437]},
#  30: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3842, 5067]},
#  31: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3111, 2034]},
#  32: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4910, 5714]},
#  33: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2163, 2356]},
#  34: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2447, 2075]},
#  35: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1002, 2282]},
#  36: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5726, 4178]},
#  37: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5375, 5584]},
#  38: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1427, 5863]},
#  39: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5096, 2682]},
#  40: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4055, 4285]},
#  41: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2873, 1797]},
#  42: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2534, 6000]},
#  43: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4506, 790]},
#  44: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3743, 574]},
#  45: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3771, 5402]},
#  46: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1969, 4743]},
#  47: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [75, 2218]},
#  48: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [6036, 4467]},
#  49: {'group_size': 2,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4495, 4662]},
#  50: {'group_size': 3,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5470, 3054, 3604]},
#  51: {'group_size': 3,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2909, 204, 1041]},
#  52: {'group_size': 3,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2307, 2898, 4151]},
#  53: {'group_size': 3,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3542, 167, 2286]},
#  54: {'group_size': 3,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [99, 4039, 4802]},
#  55: {'group_size': 3,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5573, 2581, 1034]},
#  56: {'group_size': 3,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1518, 3645, 5603]},
#  57: {'group_size': 3,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3148, 398, 2971]},
#  58: {'group_size': 3,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [6014, 4944, 3099]},
#  59: {'group_size': 3,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [187, 5792, 1569]},
#  60: {'group_size': 3,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4001, 3713, 193]},
#  61: {'group_size': 3,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [
{'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2757, 3270, 28, 2709]},
#  144: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4701, 5665, 3249, 1633]},
#  145: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [575, 3995, 418, 1258]},
#  146: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1925, 2288, 5077, 729]},
#  147: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5119, 619, 1459, 3744]},
#  148: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2792, 4532, 3746, 5395]},
#  149: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1455, 1065, 1951, 3063]},
#  150: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4168, 1227, 1963, 2560, 740]},
#  151: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2693, 4408, 2805, 2975, 3988]},
#  152: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2069, 2547, 5180, 2753, 619]},
#  153: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5380, 5154, 4871, 4698, 2944]},
#  154: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1864, 821, 1729, 1893, 1241]},
#  155: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4493, 3039, 473, 4255, 2692]},
#  156: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4693, 437, 5228, 2065, 3143]},
#  157: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4848, 3712, 6030, 4470, 3200]},
#  158: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3526, 710, 2627, 1904, 2868]},
#  159: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1640, 5386, 1629, 2500, 1041]},
#  160: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2769, 1325, 5668, 3274, 557]},
#  161: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3569, 2063, 272, 5367, 4769]},
#  162: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3011, 1063, 5560, 3820, 2361]},
#  163: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4730, 4230, 4045, 4804, 5358]},
#  164: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5139, 2222, 2309, 4257, 425]},
#  165: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5468, 58, 4708, 19, 4282]},
#  166: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1811, 227, 4397, 2317, 3328]},
#  167: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [819, 5436, 2017, 3955, 2289]},
#  168: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3261, 2778, 3002, 839, 3720]},
#  169: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [259, 5458, 5161, 4070, 1638]},
#  170: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4692, 4651, 5586, 5610, 3045]},
#  171: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5424, 3260, 5790, 2303, 2006]},
#  172: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2374, 4279, 2522, 5894, 2339]},
#  173: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2367, 683, 103, 4441, 1072]},
#  174: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2743, 2642, 2603, 4404, 3543]},
#  175: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [809, 1345, 3232, 4036, 2715]},
#  176: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4898, 2826, 173, 3635, 2202]},
#  177: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5636, 4964, 3313, 4509, 5456]},
#  178: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3639, 2754, 1367, 31, 4498]},
#  179: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3806, 1424, 741, 3677, 3605]},
#  180: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3828, 5187, 2284, 1860, 5098]},
#  181: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5362, 5310, 4888, 5667, 535]},
#  182: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4597, 4623, 5117, 2199, 3797]},
#  183: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2280, 1973, 1161, 1863, 5549]},
#  184: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4959, 5404, 5908, 1800, 5152]},
#  185: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1597, 737, 2122, 2793, 1144]},
#  186: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [961, 5360, 5863, 2669, 2539]},
#  187: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2050, 1831, 4397, 5246, 4788]},
#  188: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5292, 5315, 1269, 4263, 1991]},
#  189: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [179, 3169, 5474, 5186, 2882]},
#  190: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [413, 728, 5998, 1376, 1062]},
#  191: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1861, 3705, 5689, 2937, 3955]},
#  192: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4351, 2576, 5645, 3327, 5763]},
#  193: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [182, 5198, 2987, 3557, 1339]},
#  194: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1827, 2415, 1108, 2399, 566]},
#  195: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4062, 2077, 2060, 1139, 4311]},
#  196: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4053, 2665, 3681, 669, 933]},
#  197: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2800, 4329, 531, 4347, 2268]},
#  198: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4181, 2536, 1881, 3766, 1630]},
#  199: {'group_size': 5,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3323, 5722, 2288, 3402, 4764]}}

# %%
np.set_printoptions(precision=4, suppress=True)
idx = 80
member_index = [user_id_indexes.tolist().index(member) for member in group_dict[idx]["group_members"]]
s = sim_matrix[member_index]
s[:,member_index]
# Out:
# array([[1.    , 0.3075, 0.0787],
#        [0.3075, 1.    , 0.105 ],
#        [0.0787, 0.105 , 1.    ]])

# %%
import pickle
pickle.dump(group_dict, open(preprocessed_dataset_folder+"/group_composition.pkl", "wb"))
